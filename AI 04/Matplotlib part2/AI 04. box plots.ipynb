# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.normal(0,1, 100)

# %%
data
# Out:
# array([-1.27495096,  0.04315182,  1.77466979,  0.31814923, -1.44100458,
#         0.51155844, -1.16700303,  0.70734848, -0.7943708 ,  1.17981045,
#        -0.89010254, -0.09144618,  0.31058261,  0.64535108,  0.32778098,
#         0.42017512, -1.0656576 ,  0.19677314, -0.37456201,  1.54916201,
#        -0.04628139, -0.02548301, -1.27804847,  1.10170518, -0.31705536,
#         0.26407026, -1.42697539, -0.79917149,  0.4770469 ,  0.84980407,
#        -0.55442469,  0.56310115,  0.36604743, -0.42349809,  0.38702052,
#        -0.30258735, -0.53790182, -0.39385535, -1.5994583 ,  0.64893483,
#        -0.11270532,  0.77909055,  0.85777905, -0.73213932,  1.53981416,
#         1.16412797,  0.27558539, -0.05866014,  0.30398686,  0.91176016,
#        -2.49337255, -0.26855877, -1.1502376 , -0.63174831, -0.08273255,
#         0.82036194, -1.4720241 ,  0.94736385, -0.82002594, -3.3626528 ,
#         0.36740043,  0.0646034 ,  1.04218101, -0.30854789, -0.70817061,
# ...

# %%
plt.boxplot(data);

# %%
datas = [np.random.normal(0,1, 100), np.random.normal(3,1.5, 100), np.random.normal(-5,0.3, 100)]
plt.boxplot(datas, tick_labels=['Normal A', 'Normal B', 'Normal C'])
plt.show()
